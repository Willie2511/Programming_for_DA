# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# <h1><center> Numpy.Random Overview </center></h1>

# %% [markdown]
# To Do:
#
# 1. Explain the overall purpose of the package.
# 2. Explain the use of the “Simple random data” and “Permutations” functions.
# 3. Explain the use and purpose of at least five “Distributions” functions.
# 4. Explain the use of seeds in generating pseudorandom numbers.
#
# ***

# %% [markdown]
# NumPy is the fundamental package for scientific computing with Python (Midha, 2019). Created in 2005 by Travis Oliphant, NumPy (Numerical Python) is an open source Python library, which is the universal standard for working with numerical data in Python. Numpy is at the core of the scientific Python and PyData ecosystems. It also has functions for working in domain of linear algebra, fourier transform, and matrices (Numpy.org, 2020). Numpy is an extremely important library in the world of Data Science and analytics, on which almost every data science or machine learning Python packages such as SciPy (Scientific Python), Mat−plotlib (plotting library), and Scikit-learn depends on. Numpy has the ability to generate random lists of data, shuffle existing data, and draw samples based on a specified distribution. The Numpy.random module supplements the built-in Python random with functions for efficiently generating whole arrays of sample values from many kinds of probability distributions. As this paper will focus on the numpy.random package, it will explain the use of sample random data and permutations function, some distributions functions, and explain the use of seeds in generating pseudorandom numbers. Many projects in the data anaylitics world begin with importing the numpy library.

# %%
import numpy as np

# %% [markdown]
# Amoung other essential Python packages as mentioned above.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# We will begin by looking at pseudorandom number generation and the important function of seeds in this generation  process.

# %% [markdown]
# # <h1><center>Seeds - Pseudorandom Number Generation </center></h1>

# %% [markdown]
# #### Pseudorandom Number Generation
#
# A pseudorandom number generator (PRNG) is a deterministic algorithm capable of generating sequences of numbers that approximate the properties of random numbers (Tsakalaki,2019). Numpy’s random number routines produce pseudo random numbers using combinations of a BitGenerator to create sequences, and a Generator to use those sequences to sample from different statistical distributions.
# BitGenerators are objects that generate random numbers. These are typically unsigned integer words filled with sequences of either 32 or 64 random bits.
# Generators are objects that transform sequences of random bits from a BitGenerator into sequences of numbers that follow a specific probability distribution (such as uniform, Normal or Binomial) within a specified interval. We will first look at the importance of the seed in a pseudorandom sequence, before diving into more depth on Generators and BitGenerators.
#
#
# #### The Seed
#
# The seed is a starting point for a sequence of pseudorandom numbers, thus meaning it is not truly random. If you start from the same seed, you get the very same sequence. Pseudorandom sequences must eventually repeat, occuring when the algorithm reaches a seed it has previously used. The 'Period' is the name given to the length before a pseudorandom sequence repeats. The creation of such sequences from a selected seed has long been a cause for concern in regards security and hacking of data. If a two digit seed was selected, then the alogrithm can produce at most 100 numbers before re-using a seed and repeating the cycle (KhanAcademyLabs, 2014).
#
# In Numpy.random we have a seed function called np.random.seed(), which allows for the specification of the seed value in Numpys Random Number Generator. The output that you get depends on the input that you give it. If you provide the same seed, you will get the same output, And if you change the seed, you will get a different output (Ebner, 2019). The only parameter in the syntax of NumPy random seed is the seed value. Numpy.random.seed() works in conjunction with other functions in the numpy library, many of which will be explained in the Simple Random Data section of the paper. See below for a couple of simple examples of the numpy.random.seed() funciton

# %%
import numpy as np
np.random.seed(1)
np.random.random()
# Out:
# 0.417022004702574

# %%
np.random.seed(2)
np.random.randint(0,100,5)
# Out:
# array([40, 15, 72, 22, 43])

# %% [markdown]
# #### The Mersenne Twister
#
# The Mersenne Twister (MT) is a strong pseudorandom number generator, and is one of the most highly recommended and used PNGs. Python uses the Mersenne Twister as the core generator. The MT has an inordinately huge period of 2^19937 – 1. One of the strengths of the MT19937 lies in the fact that one 32-bit value produced by it cannot be used to predict the subsequent 32-bit value. The MT19937 algorithm keeps track of its state in 624 32-bit values. However, there is also the MT19937-64 which uses a 64-bit values. If an attacker were able to gather 624 sequential values, then the entire sequence—forward and backward—could be reverse-engineered, meaning after 624 outputs, we can completely predict its output. (Shema, 2012).
#
# The MT generator state occupies 2504 bytes of RAM, which is substantially more than the majority of modern PNGs. It is significantly slower to produce output and also underperforms in terms of randomness. The MT fails some statistical tests in the TestU01 suite, including Crush and Big Crush. Empirical statistical tests perform checks to determine whether a random number generator produces random numbers that actually behaves the way we expect random numbers to behave. One of the most well-respected statistical test suites is TestU01 (O'Neill, 2018). The TestU01 suite is a software library offering a collection of utilities for the empirical statistical testing of uniform random number generators (L'Ecuyer and Simard, 2007). Failure in certain tests highlight the potential for bias and predictability to stain the output of PNGs.
#
# #### PCG-64
#
# One of the most efficient modern PNGs is the PCG-64 (permuted congruential generator). A simple, fast, space-efficient statistically good algorithm for random number generation (O'Neill, 2018). The PCG-64 outperforms the MT in every major category making it a much more advanced and accurate PNG. The biggest improvement the PCG-64 provides is in the area of speed and effieciency. The primary design goal for PCG generators is to be a fast statistically-good general purpose generators. The PCG-64 generator doubles the state space size of the PCG-32, which has state-space size of 2127 (264 period × 263 streams) and produces 32-bit outputs,and adds the nonlinearity of xor-folding to the mix (O'Neill, 2018). The PCG-64 operates with extremely compact code, which reduces Byte requirements and usage while also greatly increasing operation speeds. The PCG-64 performs significantly better than the majority of PNGs, including the MT generator, in empirical statistical tests. "The PCG uses a new technique called permutation functions on tuples to produce output that is much more random than the RNG's internal state. PCG's output functions are what gives it its excellent statistical performance and makes it hard predict from its output (and thus more secure)" (O'Neill, 2018).

# %% [markdown]
# ***

# %% [markdown]
# # <h1><center>Permutations and Simple Random Data </center></h1>
#
#
# ****
#
# ## Simple Random  Data
#
# Randomness is an integral part of the configuration and evaluation of algorithms in Data Science, Analytics, and Machine Learning (Brownlee, 2018). Having the ability to create random training and testing data sets, while being able to randomly shuffle or specify the type of data is an invaluable skill in the world of Data Science and Machine Learning. This section will focus on the numpy package for generating random arrays. The numpy.random package is a very good tool for generating simulated data, random sampling, and we will look at different functions available to generate simple random data. Each function serves a different purpose, breaking down the parameters and providing examples of each function will give a better idea of how each function works.
#
# #### np.random.rand()
#
# The np.random.rand() function creates an array of the given shape and propagates it with random samples from a uniform distribution over [0, 1]. The parameter for this function is the dimensions of the returned array. See below

# %%
import numpy as np
np.random.rand(4,2)
# Out:
# array([[0.69345291, 0.60139009],
#        [0.13175227, 0.96499992],
#        [0.53424404, 0.69818766],
#        [0.06752429, 0.45318393]])

# %% [markdown]
# #### np.random.randn()
#
# The numpy.random.randn() function creates an array of specified shape and fills it with random values as per standard normal distribution. If positive arguments are provided, randn generates an array of shape (d0, d1, …, dn), filled with random floats sampled from a “normal” distribution of mean 0 and standard deviation of 1 (SciPy.org, 2020). See example of function below

# %%
import numpy as np
np.random.randn(2,3)
# Out:
# array([[-0.7007565 ,  0.7665143 , -0.49679931],
#        [-0.13641112, -0.02020001,  0.21039126]])

# %% [markdown]
# #### np.random.randint()
#
# The randint() function takes three arguments, the lower end of the range, the upper end of the range, and the number of integer values to generate or the size of the array (Brownlee, 2018). Random integers will be drawn from the “discrete uniform” distribution (a symmetric probability distribution wherein a finite number of values are equally likely to be observed) including the lower value and excluding the upper value(SciPy.org, 2020). See example of function below

# %%
import numpy as np
np.random.randint(5, size=(2, 3))
# Out:
# array([[3, 4, 3],
#        [2, 4, 4]])

# %% [markdown]
# #### np.random.choice()
#
# The choice() function takes an array as a parameter and randomly returns one of the values. There are four parameters for the NumPy random choice function 1. a = The array to operate on 2. size = the size, or shape, of the output array 3. replace = Whether the sample is with or without replacement 4. p = the probabilities associated with the elements of the input array. Parameters 2, 3 and 4 are all optional. Please see example of function below

# %%
import numpy as np
np.random.choice(5, 3)
# Out:
# array([3, 4, 4])

# %%
import numpy as np

x = np.random.choice([3,4,5], size=(3,4))
print(x)
# Out:
# [[4 3 4 4]
#  [4 5 5 3]
#  [5 5 3 4]]

# %% [markdown]
# ***
# ## Permutations
#
# A permutation, also called an “arrangement number” or “order”, is a rearrangement of the elements of an ordered list  into a one-to-one correspondence with itself. The permutation() method returns a re-arranged array, and leaves the original array un-changed(e.g. [3, 2, 1] is a permutation of [1, 2, 3] and vice-versa.) (Mishra, 2020).
# Python provide direct methods to find permutations and combinations of a sequence. The Numpy.random.permutation() function and the permutation function from the itertools package are two ways in which we can randomly permute a sequence, or return a permuted range. While this paper is focused solely on the numpy.random() function, I will provide a short example of both methods. First I will present the itertools method. Step number one is to import the permutations function from the python package 'itertools'.

# %%
from itertools import permutations

# %% [markdown]
# There are two parameters we have to deal with when using this function. The first is the iterable whose permutations we want, -eg. list, string, tuple, and the second is size, which is the number of elements in each permutation. See example below.

# %%
#[1,2,3] is the iterable while 2 is the number of elements in each permutation.
a=permutations ([1,2,3],2) 
for i in a:
    print(i)
# Out:
# (1, 2)
# (1, 3)
# (2, 1)
# (2, 3)
# (3, 1)
# (3, 2)

# %% [markdown]
# If we were to leave out the size parameter, the default value is set as the length of the iterable (Pythonpool, 2020).

# %%
a=permutations ([2,3,4])
for i in a:
    print(i)
# Out:
# (2, 3, 4)
# (2, 4, 3)
# (3, 2, 4)
# (3, 4, 2)
# (4, 2, 3)
# (4, 3, 2)

# %% [markdown]
# The second method for randomly permuting a sequence is using the numpy.random.permutation() function. In a function numpy.random.permutation(x), if x is an integer, randomly permute np.arange(x). If x is an array, make a copy and shuffle the elements randomly. We begin by importing numpy.

# %%
import numpy as np

# %% [markdown]
# As highlighted in the parameters above, if x is an integer, numpy will randomly permute np.arange(x). See below

# %%
np.random.permutation(9)
# Out:
# array([8, 0, 5, 1, 3, 2, 4, 6, 7])

# %% [markdown]
# If x is an array, numpy makes a copy and shuffles the elements randomly. See below

# %%
np.random.permutation([2, 5, 11, 6, 19])
# Out:
# array([19,  6, 11,  5,  2])

# %% [markdown]
# We can also specify the shape in which the array is returned using the .arange and .reshape functions. See below

# %%
arr = np.arange(8).reshape((2, 4))
np.random.permutation(arr)
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %% [markdown]
# While the permutation() method returns a re-arranged array, and leaves the original array un-changed, shuffle() means changing arrangement of elements in-place. i.e. in the array itself. If np.random.permutation is passed an array, it will return a shuffled copy of the array; np.random.shuffle shuffles the array inplace. Shuffle returns None, which means there is no return value, and permutation returns the scrambled array. Another major difference between the permutations function and the shuffle function is that shuffle only accepts arrays or lists as input.

# %%
arr = np.arange(8)
np.random.shuffle(arr)

# %% [markdown]
# ***
#
#
# # Distributions
#
# ****
#
# Data can be distributed in many ways, six of which we will take a look at in this section. Each distribution will be explained using examples and graphs created using numpy.random, matplotlib.pyplot, and seaborn. Matplotlib.pyplot is mainly intended for interactive plots and simple cases of programmatic plot generation, while Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics (Waskom, 2020).
#
# Before breaking down a number of distributions we must first understand both discrete and continuous probability distributions. All probability distributions can be classified as discrete probability distributions or as continuous probability distributions, depending on whether they define probabilities associated with discrete variables or continuous variables (StatTrek, 2020).  A simple explanation of the difference between discrete and continuous variables can be explained as: If a variable can take on any value between two specified values, it is called a continuous variable, otherwise, it is called a discrete variable. And in regards to probability distributions, if a random variable is a discrete variable, its probability distribution is called a discrete probability distribution. Similarly, if a random variable is a continuous variable, its probability distribution is called a continuous probability distribution (StatTrek, 2020).
#
#
#
#
# #### Normal Distribution
#
# The Normal Distribution, also called the Gaussian Distribution, is one of the most important distributions.
# It occurs where the data tends to be around a central value with no bias left or right, thus when it is represented in graph form it produces a "bell curve". It fits the probability distribution of many events, including IQ Scores, Heartbeat, heights of people, errors in measurements etc.
# In order to create a normal distribution in numpy we simply use the random.normal() method. The function has three parameters: 1. loc(Mean) - where the peak of the bell exists 2. scale (standard deviation) - a measure of how spread out numbers are and how flat the graph distribution should be 3. size - The shape of the returned array (w3schools, 2020). See example of normal distribution below

# %%
import numpy as np

x = np.random.normal(loc=1, scale=2, size=(3, 5))
print(x)
# Out:
# [[ 1.82519037  1.32752659  0.9848787   2.09098228 -0.67644958]
#  [ 2.71819544 -4.69067065  2.62827314  3.19960664  3.5280497 ]
#  [ 4.26651832  2.5841155   0.54111826  1.20582315  2.68406497]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(np.random.normal(size=5000), hist=False)

plt.show()

# %% [markdown]
# *****
#
#
# #### Uniform Distribution
#
# A uniform distribution is a type of probability distribution in which all outcomes are equally likely. There are many different types of probability distributions, and the uniform distribution is perhaps the simplest of them all (Chen, 2020). In order to create a random samples from the uniform distribution we will use the random.uniform() function. This function has three parameters: 1. Low - the lower boundary of the output interval 2. High - upper boundary of the output interval. All values generated will be less than high 3. Size - Output shape. Samples are uniformly distributed over the half-open interval. See example of uniform distribution below

# %%
x = np.random.uniform(0,1,500)

# %%
count, bins, ignored = plt.hist(x, 15, density=True)
# Red line included to show the probability density function
plt.plot(bins, np.ones_like(bins), linewidth=2, color='r')
plt.show()

# %% [markdown]
# *****
#
# #### Gamma Distribution
# With the help of numpy.random.gamma() method, we can get the random samples of gamma distribution and return the random samples of numpy array by using this method.
#
# ****
# #### Poisson Distribution
#
# Poisson Distribution is a Discrete Distribution. A Poisson Process is a model for a series of discrete events where the average time between events is known, but the exact timing of events is random (Koehrsen, 2019). The numpy.random.poisson function draws samples from a Poisson distribution, and it has two parameters 1. lam - rate or known number of occurences 2. size - The shape of the returned array. See example of poisson distribution below

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(np.random.poisson(lam=5, size=1000), kde=False)

plt.show()

# %% [markdown]
# ****
# #### Exponential Distribution
#
# The exponential distribution is often used to model the time elapsed between events. It is strongly related to the poisson distribution (see above). Poisson distribution deals with number of occurences of an event in a time period whereas exponential distribution deals with the time between these events (w3schools, 2020). If an event can occur more than once and the time elapsed between two successive occurrences is exponentially distributed and independent of previous occurrences, then the number of occurrences of the event within a given unit of time has a Poisson distribution (Taboga, 2017). Using the numpy.random.exponential() function, we can produce random samples from exponential distribution and returns the numpy array of samples. The function has two parameters 1. scale - inverse of rate (lam in poisson distribution) which defaults to 1.0, and 2. size - The shape of the returned array. See example of the numpy.random.exponential() function below.

# %%
import numpy as np 
import matplotlib.pyplot as plt 

exp = np.random.exponential(2.50, 5000) 
# Will produce a histogram to represent data
count, bins, ignored = plt.hist(exp, 14, density = True) 
plt.show()

# %%
import seaborn as sns
# Use of distplot in seaborn for a different visual
sns.distplot(np.random.exponential(size=5000), hist=False)

plt.show()

# %% [markdown]
# ****
#
# #### Poisson Distribution
#
# Poisson Distribution is a Discrete Distribution.
#
# It estimates how many times an event can happen in a specified time. e.g. If someone eats twice a day what is probability he will eat thrice?
#
# It has two parameters:
#
# lam - rate or known number of occurences e.g. 2 for above problem.
#
# size - The shape of the returned array.
#
# ****
#
# #### Bionomial Distribution
#
# Binomial Distribution is a Discrete Distribution.
#
# It describes the outcome of binary scenarios, e.g. toss of a coin, it will either be head or tails.
#
# It has three parameters:
#
# n - number of trials.
#
# p - probability of occurence of each trial (e.g. for toss of a coin 0.5 each).
#
# size - The shape of the returned array.
#
# A Binomial Distribution is used to model the probability of the number of successes we can expect from n trials with a probability p. The Poisson Distribution is a special case of the Binomial Distribution as n goes to infinity while the expected number of successes remains fixed. The Poisson is used as an approximation of the Binomial if n is large and p is small.
#
#  ****
#
# #### Logistic Distribution
#
# Logistic Distribution is used to describe growth.
#
# Used extensively in machine learning in logistic regression, neural networks etc.
#
# It has three parameters:
#
# loc - mean, where the peak is. Default 0.
#
# scale - standard deviation, the flatness of distribution. Default 1.
#
# size - The shape of the returned array.
#
# ****
#
# #### Multinomial Distribution
#
# Multinomial distribution is a generalization of binomial distribution.
#
# It describes outcomes of multi-nomial scenarios unlike binomial where scenarios must be only one of two. e.g. Blood type of a population, dice roll outcome.
#
# It has three parameters:
#
# n - number of possible outcomes (e.g. 6 for dice roll).
#
# pvals - list of probabilties of outcomes (e.g. [1/6, 1/6, 1/6, 1/6, 1/6, 1/6] for dice roll).
#
# size - The shape of the returned array.
#
# ****
#
# ### All info accessed on: https://www.w3schools.com/python/numpy_random_multinomial.asp

# %% [markdown]
# ***
#
# ## Other useful link : https://het.as.utexas.edu/HET/Software/Numpy/reference/routines.random.html

# %% [markdown]
# # Bibliography
#
#
# Chen, J., 2020. "Uniform Distribution" Investopedia. Available at: https://www.investopedia.com/terms/u/uniform-distribution.asp Accessed on: 19/11/2020.
#
# Ebner, J., 2019. "NUMPY RANDOM SEED EXPLAINED" Sharp Sight Labs. Available at: https://www.sharpsightlabs.com/blog/numpy-random-seed/ Accessed on: 18/11/2020.
#
# McKinney, W., 2012. Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".
#
# Javapoint, 2020. Numpy.random () in Python. JavaPoint. Available at: https://www.javatpoint.com/numpy-random Accessed on: 04/11/2020.
#
# Khan Academy Labs, 2014. 'Pseudorandom number generators | Computer Science' Khan Academy Labs. Available at: https://www.youtube.com/watch?v=GtOt7EBNEwQ Accessed on: 14/11/2020.
#
# Koehrsen, W., 2019. "The Poisson Distribution and Poisson Process Explained" Towards Data Science. Available at: https://towardsdatascience.com/the-poisson-distribution-and-poisson-process-explained-4e2cb17d459 Accessed on: 19/11/2020.
#
# L'Ecuyer, P. and Simard, R., 2007. "TestU01: A C library for empirical testing of random number generators" ACM Transactions on Mathematical Software. Available at: https://dl.acm.org/doi/10.1145/1268776.1268777 Accessed on: 17/11/2020.
#
# Lidl, R. and Niederreiter, H., 1994. Introduction to finite fields and their applications. Cambridge university press.
#
# Midha, R., 2019. "Numpy-Explained!" Data Camp. Available at: https://www.datacamp.com/community/news/numpy-explained-r5yarl75l7 Accessed on: 10/11/2020.
#
# Mishra, S., 2020. "Python | Permutation of a given string using inbuilt function" GeeksforGeeks. Available at: https://www.geeksforgeeks.org/python-permutation-given-string-using-inbuilt-function/  Accessed on: 10/11/2020.
#
# O'Neill, M.E., 2018. "Predictability" PCG Random. Available at: https://www.pcg-random.org/predictability.html Accessed on: 18/11/2020.
#
# O'Neill, M.E., 2018. "Empirical Statistical Tests" PCG Random. Available at: https://www.pcg-random.org/index.html Accessed on: 17/11/2020.
#
# O'Neill, M.E., 2018. "PCG, A Family of Better Random Number Generators" PCG Random. Available at: https://www.pcg-random.org/index.html Accessed on: 17/11/2020.
#
# Pythonpool, 2020. "Understanding Python Permutations function with examples" PythonPool. Available at: https://www.pythonpool.com/python-permutations/ Accessed on: 09/11/2020.
#
# Shema, M., 2012. "Leveraging Platform Weaknesses" Hacking Web Apps. Available at: https://www.sciencedirect.com/topics/computer-science/mersenne-twister Accessed on: 17/11/2020.
#
# StatTrek, 2020. "Probability Distributions: Discrete vs. Continuous" Stat Trek. Available at: https://stattrek.com/probability-distributions/discrete-continuous.aspx Accessed on: 19/11/2020.
#
#
# Taboga, M., 2017. "Exponential distribution" StatLect. Available at: https://www.statlect.com/probability-distributions/exponential-distribution Accessed on: 19/11/2020.
#
# Tsakalaki, M., 2019. "Properly seed pseudorandom number generators" Carnegie Mellon University. Available at: https://wiki.sei.cmu.edu/confluence/display/c/MSC32-C.+Properly+seed+pseudorandom+number+generators Accessed on: 14/11/2020.
#
# Waskom, M., 2020. "seaborn: statistical data visualization" Seaborn. Available at: https://seaborn.pydata.org/ Accessed on: 19/11/2020.
#
# w3schools, 2020. "Normal (Gaussian) Distribution" w3schools. Available at: https://www.w3schools.com/python/numpy_random_normal.asp Accessed on: 19/11/2020.
#
# w3schools, 2020. "Exponential Distribution" w3schools. Available at: https://www.w3schools.com/python/numpy_random_exponential.asp Accessed on: 19/11/2020.
