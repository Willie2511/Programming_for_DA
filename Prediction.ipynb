# %%
import sklearn.neighbors as nei
import pandas as pd
import sklearn.model_selection as mod

# %%
df = pd.read_csv("/Users/Willie/Downloads/iris_csv.csv")

# %%
df.describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue="class")

# %%
inputs = df[['sepallength', 'sepalwidth', 'petallength', 'petalwidth']]
outputs = df['class']

# %%
knn = nei.KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(inputs, outputs)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
df.loc[0]
# Out:
# sepallength            5.1
# sepalwidth             3.5
# petallength            1.4
# petalwidth             0.2
# class          Iris-setosa
# Name: 0, dtype: object

# %%
knn.predict([[5.2, 3.5, 1.4, 0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
knn.predict([[5.6, 2.8, 4.9, 2.0]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
(knn.predict(inputs) == outputs).sum()
# Out:
# 145

# %%
inputs_train, inputs_test, outputs_train, outputs_test = mod.train_test_split(inputs, outputs, test_size=0.33)
# Out:
# [     sepallength  sepalwidth  petallength  petalwidth
#  109          7.2         3.6          6.1         2.5
#  131          7.9         3.8          6.4         2.0
#  28           5.2         3.4          1.4         0.2
#  105          7.6         3.0          6.6         2.1
#  58           6.6         2.9          4.6         1.3
#  ..           ...         ...          ...         ...
#  140          6.7         3.1          5.6         2.4
#  32           5.2         4.1          1.5         0.1
#  132          6.4         2.8          5.6         2.2
#  107          7.3         2.9          6.3         1.8
#  86           6.7         3.1          4.7         1.5
#
#  [100 rows x 4 columns],      sepallength  sepalwidth  petallength  petalwidth
#  79           5.7         2.6          3.5         1.0
#  68           6.2         2.2          4.5         1.5
#  117          7.7         3.8          6.7         2.2
#  39           5.1         3.4          1.5         0.2
#  60           5.0         2.0          3.5         1.0
#  22           4.6         3.6          1.0         0.2
#  2            4.7         3.2          1.3         0.2
#  129          7.2         3.0          5.8         1.6
#  35           5.0         3.2          1.2         0.2
#  47           4.6         3.2          1.4         0.2
#  59           5.2         2.7          3.9         1.4
#  83           6.0         2.7          5.1         1.6
#  8            4.4         2.9          1.4         0.2
#  80           5.5         2.4          3.8         1.1
#  63           6.1         2.9          4.7         1.4
#  104          6.5         3.0          5.8         2.2
#  0            5.1         3.5          1.4         0.2
#  65           6.7         3.1          4.4         1.4
#  25           5.0         3.0          1.6         0.2
#  103          6.3         2.9          5.6         1.8
#  37           4.9         3.1          1.5         0.1
#  71           6.1         2.8          4.0         1.3
#  78           6.0         2.9          4.5         1.5
#  87           6.3         2.3          4.4         1.3
#  145          6.7         3.0          5.2         2.3
#  124          6.7         3.3          5.7         2.1
#  138          6.0         3.0          4.8         1.8
#  74           6.4         2.9          4.3         1.3
#  84           5.4         3.0          4.5         1.5
#  126          6.2         2.8          4.8         1.8
#  137          6.4         3.1          5.5         1.8
#  16           5.4         3.9          1.3         0.4
#  122          7.7         2.8          6.7         2.0
#  34           4.9         3.1          1.5         0.1
#  85           6.0         3.4          4.5         1.6
#  52           6.9         3.1          4.9         1.5
#  56           6.3         3.3          4.7         1.6
#  6            4.6         3.4          1.4         0.3
#  29           4.7         3.2          1.6         0.2
#  40           5.0         3.5          1.3         0.3
#  115          6.4         3.2          5.3         2.3
#  147          6.5         3.0          5.2         2.0
#  123          6.3         2.7          4.9         1.8
#  141          6.9         3.1          5.1         2.3
#  118          7.7         2.6          6.9         2.3
#  26           5.0         3.4          1.6         0.4
#  102          7.1         3.0          5.9         2.1
#  90           5.5         2.6          4.4         1.2
#  82           5.8         2.7          3.9         1.2
#  7            5.0         3.4          1.5         0.2, 109     Iris-virginica
#  131     Iris-virginica
#  28         Iris-setosa
#  105     Iris-virginica
#  58     Iris-versicolor
#              ...
#  140     Iris-virginica
#  32         Iris-setosa
#  132     Iris-virginica
#  107     Iris-virginica
#  86     Iris-versicolor
#  Name: class, Length: 100, dtype: object, 79     Iris-versicolor
#  68     Iris-versicolor
#  117     Iris-virginica
#  39         Iris-setosa
#  60     Iris-versicolor
#  22         Iris-setosa
#  2          Iris-setosa
#  129     Iris-virginica
#  35         Iris-setosa
#  47         Iris-setosa
#  59     Iris-versicolor
#  83     Iris-versicolor
#  8          Iris-setosa
#  80     Iris-versicolor
#  63     Iris-versicolor
#  104     Iris-virginica
#  0          Iris-setosa
#  65     Iris-versicolor
#  25         Iris-setosa
#  103     Iris-virginica
#  37         Iris-setosa
#  71     Iris-versicolor
#  78     Iris-versicolor
#  87     Iris-versicolor
#  145     Iris-virginica
#  124     Iris-virginica
#  138     Iris-virginica
#  74     Iris-versicolor
#  84     Iris-versicolor
#  126     Iris-virginica
#  137     Iris-virginica
#  16         Iris-setosa
#  122     Iris-virginica
#  34         Iris-setosa
#  85     Iris-versicolor
#  52     Iris-versicolor
#  56     Iris-versicolor
#  6          Iris-setosa
#  29         Iris-setosa
#  40         Iris-setosa
#  115     Iris-virginica
#  147     Iris-virginica
#  123     Iris-virginica
#  141     Iris-virginica
#  118     Iris-virginica
#  26         Iris-setosa
#  102     Iris-virginica
#  90     Iris-versicolor
#  82     Iris-versicolor
#  7          Iris-setosa
#  Name: class, dtype: object]

# %%
knn = nei.KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(inputs_train, outputs_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-dba891d15c55> in <module>
# ----> 1 knn.fit(inputs_train, outputs_train)
#
# NameError: name 'inputs_train' is not defined
